# %%
import sys
print("=== sys.path ===")
for p in sys.path:
    print(p)
print()
mod = sys.modules.get('databricks')
print("databricks in sys.modules:", mod is not None)
if mod is not None:
    print("databricks.__path__:", getattr(mod, '__path__', '<none>'))

# %%
from databricks.sdk.service.cleanrooms import CleanRoomTaskRunsAPI
from databricks.sdk.core import ApiClient, Config
print("ok")
