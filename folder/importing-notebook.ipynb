# %% [markdown]
# This notebook is built to verify that Python imports within a Git folder work.
#
# Please run it:
# - interactively
# - in a Git job (straight from remote repo)
# - in a "normal" job from a Workspace clone of this repo
#
# In all cases the output should show: `Notebook exited: Hello Ala`
#
# If it fails, please check the `workspace-file-access-with-udf` and collect more data.

# %%
from libraries.gen_hello import *

res = gen_hello('Ala')
dbutils.notebook.exit(res)
